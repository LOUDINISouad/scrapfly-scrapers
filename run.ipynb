# %%
from scrapfly import ScrapeConfig, ScrapflyClient, ScrapeApiResponse

scrapfly = ScrapflyClient(key='scp-live-832d94f59ad44af58d681bf5799f9c11')

# %%
result = scrapfly.scrape(
    ScrapeConfig(
        url="https://fentech.ai/"
    )
)
result.scrape_result
# Out:
# {'log_url': 'https://scrapfly.io/dashboard/monitoring/log/01J7DP03KXYQ6FK35SPJFA8ENR',
#  'success': True,
#  'url': 'https://fentech.ai/',
#  'request_headers': {'sec-ch-ua-mobile': '?0', 'sec-fetch-site': 'none', 'accept-language': 'pt-BR,pt-PT;q=0.9,en-US;q=0.8', 'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/128.0.0.0 Safari/537.36', 'sec-ch-ua': '"Chromium";v="128", "Not;A=Brand";v="24", "Google Chrome";v="128"', 'sec-ch-ua-platform': '"Linux"', 'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7', 'priority': 'u=0, i', 'sec-fetch-mode': 'navigate', 'sec-fetch-dest': 'document', 'accept-encoding': 'gzip, deflate, br, zstd', 'upgrade-insecure-requests': '1', 'sec-fetch-user': '?1', 'host': 'fentech.ai'},
#  'status_code': 200,
#  'reason': 'OK',
#  'iframes': [],
#  'extracted_data': None,
#  'status': 'DONE',
# ...
